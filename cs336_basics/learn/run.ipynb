# %%
from cs336_basics.learn.bpe import *

vocab, merges = train_bpe(
        input_path="/home/nova/cs336/assignment1-basics/data/TinyStoriesV2-GPT4-valid.txt",
        vocab_size=10_000,
        special_tokens=["<|endoftext|>","<|endoftext|><|endoftext|>"],
    )
# Out:
# 100%|██████████| 27631/27631 [00:06<00:00, 4528.89it/s]

# %%
list(vocab.items())[-10:]  # show last 10 items in vocab
# Out:
# [(9990, b' suspicious'),
#  (9991, b' sly'),
#  (9992, b' sinking'),
#  (9993, b' roles'),
#  (9994, b' roamed'),
#  (9995, b' ribbit'),
#  (9996, b' respecting'),
#  (9997, b' releasing'),
#  (9998, b' refusing'),
#  (9999, b' raincoat')]

# %%
sorted(vocab.items(), key=lambda x: len(x[1]), reverse=True)
# Out:
# [(257, b'<|endoftext|><|endoftext|>'),
#  (7428, b' accomplishment'),
#  (2956, b' uncomfortable'),
#  (3677, b' compassionate'),
#  (5238, b' understanding'),
#  (5999, b' neighbourhood'),
#  (6353, b' Unfortunately'),
#  (7053, b' determination'),
#  (7899, b' encouragement'),
#  (256, b'<|endoftext|>'),
#  (3676, b' disappointed'),
#  (3829, b' refrigerator'),
#  (4140, b' enthusiastic'),
#  (4146, b' accidentally'),
#  (4449, b' strawberries'),
#  (4481, b' veterinarian'),
#  (5678, b' neighborhood'),
#  (6099, b' instructions'),
#  (6312, b'Unfortunately'),
#  (6742, b' firefighters'),
#  (6911, b' surroundings'),
#  (6949, b' consequences'),
#  (7415, b' caterpillars'),
#  (8427, b' appreciation'),
#  (8428, b' anticipation'),
#  (8599, b' thundercloud'),
#  (8704, b' disagreement'),
#  (9016, b' particularly'),
#  (9047, b' intelligence'),
#  (9090, b' demonstrated'),
#  (9133, b' accomplished'),
#  (9394, b' successfully'),
#  (9502, b' grandparents'),
# ...
